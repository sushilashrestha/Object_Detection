# %%
import cv2
import os
import selectivesearch
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'c:\\Users\\sussh\\Documents\\CODES\\Python\\python_phase2\\Object_Detection'

# %%
img = cv2.imread('test.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
imgs, regions = selectivesearch.selective_search(img, scale=100, min_size=50)

# %%
plt.imshow(imgs[:,:,3])
plt.axis('off')
plt.show()

# %%
len(regions)
regions[:10]
# Out:
# [{'rect': (0, 0, 255, 44), 'size': 9184, 'labels': [np.float64(0.0)]},
#  {'rect': (89, 24, 32, 16), 'size': 112, 'labels': [np.float64(1.0)]},
#  {'rect': (64, 26, 21, 10), 'size': 53, 'labels': [np.float64(2.0)]},
#  {'rect': (154, 27, 51, 8), 'size': 81, 'labels': [np.float64(3.0)]},
#  {'rect': (64, 28, 38, 12), 'size': 55, 'labels': [np.float64(4.0)]},
#  {'rect': (206, 28, 49, 18), 'size': 138, 'labels': [np.float64(5.0)]},
#  {'rect': (77, 29, 25, 18), 'size': 251, 'labels': [np.float64(6.0)]},
#  {'rect': (122, 29, 90, 17), 'size': 207, 'labels': [np.float64(7.0)]},
#  {'rect': (46, 30, 35, 12), 'size': 55, 'labels': [np.float64(8.0)]},
#  {'rect': (212, 32, 35, 24), 'size': 241, 'labels': [np.float64(9.0)]}]

# %%
def extract_candidates(img):
    _, regions = selectivesearch.selective_search(img, scale=100, min_size=50)
    candidates = []
    img_area = np.prod(img.shape[:2])
    for region in regions:
        if region['rect'] in candidates:
            continue
        if region['size'] < 0.05*img_area:
            continue
        if region['size'] > img_area:
            continue 
        candidates.append(region['rect'])
    return candidates

extract_candidates(img)
# Out:
# [(0, 0, 255, 44),
#  (115, 102, 140, 68),
#  (24, 105, 169, 55),
#  (0, 29, 145, 51),
#  (0, 127, 124, 43),
#  (34, 69, 128, 50),
#  (0, 0, 255, 46),
#  (34, 42, 146, 77),
#  (0, 29, 145, 53),
#  (0, 102, 255, 68),
#  (0, 65, 142, 48),
#  (0, 64, 142, 49),
#  (52, 70, 203, 80),
#  (171, 32, 84, 60),
#  (34, 32, 221, 87),
#  (0, 64, 142, 53),
#  (21, 103, 172, 57),
#  (0, 103, 193, 57),
#  (0, 29, 146, 53),
#  (0, 32, 255, 87),
#  (0, 26, 255, 93),
#  (0, 26, 255, 103),
#  (0, 70, 255, 100),
#  (0, 26, 255, 144),
#  (0, 0, 255, 170)]
